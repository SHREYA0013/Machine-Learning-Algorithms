# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import statsmodels.formula.api as sm
from sklearn.linear_model import LinearRegression
from scipy import stats

# %%
table=pd.read_excel("C:/Projects/Machine-Learning-Algorithms/Linear Regression/LR-1(Laptop Sales).xlsx")

# %%
table
# Out:
#     no of laptops sold  no of ads per hour
# 0                    5                   2
# 1                    7                   4
# 2                    6                   3
# 3                   14                   8
# 4                    3                   1
# 5                    1                   0
# 6                   15                   9
# 7                   15                  10
# 8                   19                  11
# 9                   20                  14
# 10                  28                  19
# 11                  10                   5

# %%
table.plot('no of ads per hour','no of laptops sold')
# Out:
# <Axes: xlabel='no of ads per hour'>

# %%
table.plot('no of ads per hour','no of laptops sold',style='o')
# Out:
# <Axes: xlabel='no of ads per hour'>

# %% [markdown]
# There is a positive linear relationship.As the advertisements increases the no of Laptops sold also increases. We have an outlier in our data,we can add more values to remove it.

# %%
table.plot('no of ads per hour','no of laptops sold',style='o')
plt.title('Laptops Sell with TV ads')
plt.ylabel('Laptops sold')
plt.xlabel('Advertisement/hour')
plt.show()

# %%
a = table['no of ads per hour']
l = table['no of laptops sold']

# %%
import statsmodels.api as s
a=s.add_constant(a)
model=s.OLS(l,a)
result=model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     no of laptops sold   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                     721.1
# Date:                Thu, 22 Feb 2024   Prob (F-statistic):           1.18e-10
# Time:                        00:20:54   Log-Likelihood:                -15.731
# No. Observations:                  12   AIC:                             35.46
# Df Residuals:                      10   BIC:                             36.43
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  1.9659      0.467      4.212      0.002       0.926       3.006
# ...
